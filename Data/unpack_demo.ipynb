# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open('GEDI_sample_for_CS237_2024.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['y', 'rh', 'prop', 'prop_rh'])

# %%
plt.plot(data['y'][3])  # y: energy , x: height

# %%
plt.plot(data['rh'][3])  # x: percent energy, y: meters

# %%
print(data['prop'][3])
# Out:
# {'rx_sample_start_index': 167866721.0, 'rx_sample_count': 964.0, 'geolocation/latitude_bin0': 44.6875931257366, 'geolocation/longitude_bin0': -76.39484304768297, 'geolocation/elevation_bin0': 229.30674298945814, 'geolocation/elevation_lastbin': 85.00304012559354, 'geolocation/delta_time': 48312744.80215945, 'shot_number': 3.3120600200285944e+16, 'quality_flag': 1.0, 'sensitivity': 0.9903804659843445, 'solar_elevation': -22.226377487182617, 'degrade_flag': 0.0, 'elev_lowestmode': 152.397216796875, 'elev_highestreturn': 184.9517059326172, 'land_cover_data/landsat_treecover': 55.0, 'land_cover_data/modis_nonvegetated': 22.0, 'land_cover_data/modis_treecover': 48.0, 'delta_time': 48312744.80215945, 'rh_0': -4.679999828338623, 'rh_25': 7.449999809265137, 'rh_50': 12.430000305175781, 'rh_75': 17.559999465942383, 'rh_98': 29.59000015258789, 'surface_flag': 1.0}

# %%
print(data['prop_rh'][3])
# Out:
# {'rx_sample_start_index': 167866721, 'rx_sample_count': 964, 'geolocation/latitude_bin0': 44.6875931257366, 'geolocation/longitude_bin0': -76.39484304768297, 'geolocation/elevation_bin0': 229.30674298945814, 'geolocation/elevation_lastbin': 85.00304012559354, 'geolocation/delta_time': 48312744.80215945, 'shot_number': 33120600200285944, 'quality_flag': 1, 'sensitivity': 0.9903804659843445, 'solar_elevation': -22.226377487182617, 'degrade_flag': 0, 'elev_lowestmode': 152.397216796875, 'elev_highestreturn': 184.9517059326172, 'land_cover_data/landsat_treecover': 55.0, 'land_cover_data/modis_nonvegetated': 22.0, 'land_cover_data/modis_treecover': 48.0, 'delta_time': 48312744.80215945, 'rh_id': 118216, 'surface_flag': True}

# %%
PAD_NORM = 60
WAVE_LEN = 512
x_ind = (WAVE_LEN - PAD_NORM - np.arange(0, WAVE_LEN, 1))*0.15

plt.plot(x_ind, data['y'][3])  # x index now meters

# %%
plt.plot(x_ind, data['y'][293747])  # x index now meters

# %%
plt.plot(data['y'][3][::1])  # y: energy , x: height
# plt.plot(data['y'][3][::16])  # y: energy , x: height
