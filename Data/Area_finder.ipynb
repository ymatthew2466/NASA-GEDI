7610626,-1.585144,-2.4773712,-3.3711548,-4.2864685,-5.0690613,-5.3377686,-4.7001038,-3.101593,-0.93296814,1.1222839,2.440155,2.7914581,2.3740692,1.5763092,0.7182617,-0.045166016,-0.6149292,-0.7642822,-0.27745056,0.86343384,2.3151703,3.5038452,3.873352,3.3749084,2.4398499,1.7074127,1.4214478,1.3515472,1.0393982,0.38130188,-0.3420105,-0.7154999,-0.5063782,0.2988739,1.5007935,2.8336945,4.0195007,4.870941,5.3564606,5.513504,5.30542,4.636383,3.4991608,2.1235962,0.94781494,0.31759644,0.33595276,0.90815735,1.9904022,3.5878754,5.534317,7.360565,8.587341,9.000076,8.822678,8.511307,8.483353,8.987396,10.02475,11.318832,12.518753,13.477127,14.287201,15.140503,15.937271,16.295288,15.894089,14.926147,14.027771,13.86377,14.594406,15.836273,16.967422,17.50029,17.209824,16.25879,15.147766,14.653305,15.38121,17.336777,19.71196,21.352615,21.336136,19.645432,17.009918,14.342545,12.25473,10.968277,10.390717,10.327957,10.409836,10.250885,9.747772,9.182022,8.925171,9.251282,9.991531,10.609512,10.432022,9.2339325,7.439163,6.0025024,5.6582947,6.5055847,8.116821,10.112625,12.4513855,15.489273,19.83786,26.438293,36.59828,51.912125,73.703964,102.458664,137.61763,178.27638,223.78014,273.78815,327.19678,381.1535,430.93573,471.4018,498.7354,511.76624,511.9176,502.1745,485.826,465.7556,443.94342,421.03162,396.18573,367.65057,334.22888,296.57166,257.23828,219.66963,186.86317,160.54662,140.96611,127.11162,117.15996,109.13591,101.3918,92.97499,83.68083,73.94566,64.4442,55.58577,47.36891,39.777008,33.08902,27.786316,24.094696,21.814667,20.516815,19.877075,19.558105,19.210754,18.498703,17.32759,15.751511,13.9939575,12.249649,10.801483,9.784409,9.132172,8.491928,7.5976562,6.3229675,4.787964,3.172577,1.7666168,0.73202515,0.12080383,-0.11517334,0.08340454,0.77827454,1.9415436,3.2404633,4.41658,5.38237,6.075424,6.196121,5.5036163,4.0472107,2.4042816
]
plt.plot(test)

# %%
with open('./GEDI_sample_for_CS237_2024.pkl', 'rb') as f:
    data = pickle.load(f)
lats = np.array([prop['geolocation/latitude_bin0'] for prop in data['prop']])
lngs = np.array([prop['geolocation/longitude_bin0'] for prop in data['prop']])

# %%
PAD_NORM = 60
WAVE_LEN = 512
x_ind = (WAVE_LEN - PAD_NORM - np.arange(0, WAVE_LEN, 1))*0.15

# %%
fig, ax = plt.subplots(figsize = (10, 8))

for i, w in enumerate(data['y']):
    lng, lat = data['prop'][i]['geolocation/longitude_bin0'], data['prop'][i]['geolocation/latitude_bin0']
    if (lng>-56.9) and (lng<-56.6) and (lat>-18.2) and (lat<-17.9):
        w = w/w.sum()
        if w[-80:].sum()<0.2:
            ax.plot(x_ind, w, alpha=0.1, c='b')

# %%
fig, ax = plt.subplots(figsize = (10, 8))

area_lats = lats[(lngs>-82.7) & (lngs<-82.6) & (lats>51.7) & (lats<51.8)]
area_lngs = lngs[(lngs>-82.7) & (lngs<-82.6) & (lats>51.7) & (lats<51.8)]
# area_lats = lats
# area_lngs = lngs


ax.scatter(area_lngs, area_lats, c='r', s=0.1)
